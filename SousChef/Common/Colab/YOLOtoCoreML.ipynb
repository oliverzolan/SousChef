# %% [markdown]
# Transfer learning model using pretrained model YOLOv11.

# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
rf = Roboflow(api_key="") #removed for privacy
project = rf.workspace("segfault").project("demo_ingredients")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to demo_ingredients-1 in yolov11:: 100%|██████████| 574/574 [00:00<00:00, 6371.22it/s]

# %%
# !yolo train model=yolo11s data=/content/demo_ingredients-1/data.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 18.4M/18.4M [00:00<00:00, 161MB/s]
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !yolo export model=/content/runs/detect/train/weights/best.pt format=coreml nms=True
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11s summary (fused): 238 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
#
# PyTorch: starting from '/content/runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (18.3 MB)
# requirements: Ultralytics requirement ['coremltools>=7.0'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 35.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 253.7 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 4.5s, installed 1 package: ['coremltools>=7.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# XGBoost version 2.1.3 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.
# ...

# %%
# !zip -r best_mlpackage.zip /content/runs/detect/train/weights/best.mlpackage
# Out:
#   adding: content/runs/detect/train/weights/best.mlpackage/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.mlpackage/Manifest.json (deflated 60%)
#   adding: content/runs/detect/train/weights/best.mlpackage/Data/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.mlpackage/Data/com.apple.CoreML/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.mlpackage/Data/com.apple.CoreML/model.mlmodel (deflated 88%)
#   adding: content/runs/detect/train/weights/best.mlpackage/Data/com.apple.CoreML/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.mlpackage/Data/com.apple.CoreML/weights/weight.bin (deflated 8%)

# %%
from google.colab import files
files.download('/content/best_mlpackage.zip')
